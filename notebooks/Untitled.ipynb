# %%
import sys
# !{sys.executable} -m pip install streamlit
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting streamlit
#   Downloading streamlit-1.58.0-py3-none-any.whl.metadata (9.6 kB)
# Collecting altair!=5.4.0,!=5.4.1,<7,>=4.0 (from streamlit)
#   Downloading altair-6.2.1-py3-none-any.whl.metadata (11 kB)
# Collecting blinker<2,>=1.5.0 (from streamlit)
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting cachetools<8,>=5.5 (from streamlit)
#   Downloading cachetools-7.1.4-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: click<9,>=7.0 in C:\Users\rohan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from streamlit) (8.3.1)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Downloading gitpython-3.1.50-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy<3,>=1.23 in C:\Users\rohan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from streamlit) (2.3.5)
# Requirement already satisfied: packaging>=20 in C:\Users\rohan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from streamlit) (26.2)
# Requirement already satisfied: pandas<4,>=1.4.0 in C:\Users\rohan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from streamlit) (2.3.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in C:\Users\rohan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from streamlit) (12.2.0)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.2-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting protobuf<8,>=3.20 (from streamlit)
#   Downloading protobuf-7.35.1-cp310-abi3-win_amd64.whl.metadata (595 bytes)
# Collecting pyarrow>=7.0 (from streamlit)
#   Downloading pyarrow-24.0.0-cp313-cp313-win_amd64.whl.metadata (3.0 kB)
# Requirement already satisfied: requests<3,>=2.27 in C:\Users\rohan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from streamlit) (2.34.2)
# Collecting tenacity<10,>=8.1.0 (from streamlit)
#   Downloading tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Collecting toml<2,>=0.10.1 (from streamlit)
#   Downloading toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in C:\Users\rohan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from streamlit) (4.15.0)
# Requirement already satisfied: starlette>=0.40.0 in C:\Users\rohan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from streamlit) (0.52.1)
# Requirement already satisfied: uvicorn>=0.30.0 in C:\Users\rohan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from streamlit) (0.42.0)
# Collecting httptools>=0.6.3 (from streamlit)
#   Downloading httptools-0.8.0-cp313-cp313-win_amd64.whl.metadata (3.7 kB)
# Requirement already satisfied: anyio>=4.0.0 in C:\Users\rohan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from streamlit) (4.12.1)
# Requirement already satisfied: python-multipart>=0.0.10 in C:\Users\rohan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from streamlit) (0.0.22)
# Collecting websockets>=12.0.0 (from streamlit)
#   Downloading websockets-16.0-cp313-cp313-win_amd64.whl.metadata (7.0 kB)
# Collecting itsdangerous>=2.1.2 (from streamlit)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting watchdog<7,>=2.1.5 (from streamlit)
#   Downloading watchdog-6.0.0-py3-none-win_amd64.whl.metadata (44 kB)
# Requirement already satisfied: jinja2 in C:\Users\rohan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in C:\Users\rohan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.26.0)
# Requirement already satisfied: narwhals>=2.4.0 in C:\Users\rohan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.22.1)
# Requirement already satisfied: colorama in C:\Users\rohan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading smmap-5.0.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\rohan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pandas<4,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\rohan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pandas<4,>=1.4.0->streamlit) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\rohan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pandas<4,>=1.4.0->streamlit) (2026.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\rohan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from requests<3,>=2.27->streamlit) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\rohan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from requests<3,>=2.27->streamlit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\rohan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from requests<3,>=2.27->streamlit) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\rohan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from requests<3,>=2.27->streamlit) (2026.2.25)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\rohan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in C:\Users\rohan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\Users\rohan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\Users\rohan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in C:\Users\rohan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.30.0)
# Requirement already satisfied: six>=1.5 in C:\Users\rohan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from python-dateutil>=2.8.2->pandas<4,>=1.4.0->streamlit) (1.17.0)
# Requirement already satisfied: h11>=0.8 in C:\Users\rohan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from uvicorn>=0.30.0->streamlit) (0.16.0)
# Downloading streamlit-1.58.0-py3-none-any.whl (9.2 MB)
#    ---------------------------------------- 0.0/9.2 MB ? eta -:--:--
#    ---- ----------------------------------- 1.0/9.2 MB 5.8 MB/s eta 0:00:02
#    --------- ------------------------------ 2.1/9.2 MB 4.5 MB/s eta 0:00:02
#    ------------ --------------------------- 2.9/9.2 MB 4.4 MB/s eta 0:00:02
#    --------------- ------------------------ 3.7/9.2 MB 4.2 MB/s eta 0:00:02
#    ------------------- -------------------- 4.5/9.2 MB 4.2 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.2/9.2 MB 4.1 MB/s eta 0:00:01
#    -------------------------- ------------- 6.0/9.2 MB 4.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.8/9.2 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.9/9.2 MB 4.0 MB/s eta 0:00:01
#    ------------------------------------- -- 8.7/9.2 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------- 9.2/9.2 MB 3.9 MB/s  0:00:02
# Downloading altair-6.2.1-py3-none-any.whl (797 kB)
#    ---------------------------------------- 0.0/797.5 kB ? eta -:--:--
#    ---------------------------------------- 797.5/797.5 kB 3.7 MB/s  0:00:00
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading cachetools-7.1.4-py3-none-any.whl (16 kB)
# Downloading gitpython-3.1.50-py3-none-any.whl (212 kB)
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
# Downloading protobuf-7.35.1-cp310-abi3-win_amd64.whl (439 kB)
# Downloading pydeck-0.9.2-py2.py3-none-any.whl (11.3 MB)
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/11.3 MB 4.0 MB/s eta 0:00:03
#    ------ --------------------------------- 1.8/11.3 MB 3.9 MB/s eta 0:00:03
#    --------- ------------------------------ 2.6/11.3 MB 3.9 MB/s eta 0:00:03
#    ------------ --------------------------- 3.4/11.3 MB 3.9 MB/s eta 0:00:03
#    -------------- ------------------------- 4.2/11.3 MB 3.9 MB/s eta 0:00:02
#    ----------------- ---------------------- 5.0/11.3 MB 3.9 MB/s eta 0:00:02
#    -------------------- ------------------- 5.8/11.3 MB 3.9 MB/s eta 0:00:02
#    ----------------------- ---------------- 6.6/11.3 MB 3.9 MB/s eta 0:00:02
#    ------------------------- -------------- 7.3/11.3 MB 3.9 MB/s eta 0:00:02
#    ---------------------------- ----------- 8.1/11.3 MB 3.9 MB/s eta 0:00:01
#    -------------------------------- ------- 9.2/11.3 MB 3.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.0/11.3 MB 3.9 MB/s eta 0:00:01
#    -------------------------------------- - 10.7/11.3 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 11.3/11.3 MB 3.8 MB/s  0:00:02
# Downloading smmap-5.0.3-py3-none-any.whl (24 kB)
# Downloading tenacity-9.1.4-py3-none-any.whl (28 kB)
# Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Downloading watchdog-6.0.0-py3-none-win_amd64.whl (79 kB)
# Downloading httptools-0.8.0-cp313-cp313-win_amd64.whl (90 kB)
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading pyarrow-24.0.0-cp313-cp313-win_amd64.whl (27.3 MB)
#    ---------------------------------------- 0.0/27.3 MB ? eta -:--:--
#    - -------------------------------------- 0.8/27.3 MB 6.0 MB/s eta 0:00:05
#    -- ------------------------------------- 1.8/27.3 MB 4.4 MB/s eta 0:00:06
#    --- ------------------------------------ 2.6/27.3 MB 4.2 MB/s eta 0:00:06
#    ---- ----------------------------------- 3.4/27.3 MB 4.1 MB/s eta 0:00:06
#    ------ --------------------------------- 4.5/27.3 MB 4.1 MB/s eta 0:00:06
#    ------- -------------------------------- 5.2/27.3 MB 4.0 MB/s eta 0:00:06
#    -------- ------------------------------- 6.0/27.3 MB 4.0 MB/s eta 0:00:06
#    --------- ------------------------------ 6.8/27.3 MB 4.0 MB/s eta 0:00:06
#    ----------- ---------------------------- 7.6/27.3 MB 4.0 MB/s eta 0:00:05
#    ------------ --------------------------- 8.4/27.3 MB 4.0 MB/s eta 0:00:05
#    ------------- -------------------------- 9.2/27.3 MB 4.0 MB/s eta 0:00:05
#    -------------- ------------------------- 10.0/27.3 MB 4.0 MB/s eta 0:00:05
#    --------------- ------------------------ 10.7/27.3 MB 3.9 MB/s eta 0:00:05
#    ---------------- ----------------------- 11.5/27.3 MB 3.9 MB/s eta 0:00:04
#    ------------------ --------------------- 12.3/27.3 MB 3.9 MB/s eta 0:00:04
#    ------------------- -------------------- 13.4/27.3 MB 3.9 MB/s eta 0:00:04
#    -------------------- ------------------- 14.2/27.3 MB 3.9 MB/s eta 0:00:04
#    --------------------- ------------------ 14.9/27.3 MB 3.9 MB/s eta 0:00:04
#    ----------------------- ---------------- 15.7/27.3 MB 3.9 MB/s eta 0:00:03
#    ------------------------ --------------- 16.5/27.3 MB 3.9 MB/s eta 0:00:03
#    ------------------------- -------------- 17.3/27.3 MB 3.9 MB/s eta 0:00:03
#    -------------------------- ------------- 18.4/27.3 MB 3.9 MB/s eta 0:00:03
#    ---------------------------- ----------- 19.1/27.3 MB 3.9 MB/s eta 0:00:03
#    ----------------------------- ---------- 19.9/27.3 MB 3.9 MB/s eta 0:00:02
#    ------------------------------ --------- 20.7/27.3 MB 3.9 MB/s eta 0:00:02
#    ------------------------------- -------- 21.5/27.3 MB 3.9 MB/s eta 0:00:02
#    -------------------------------- ------- 22.3/27.3 MB 3.9 MB/s eta 0:00:02
#    --------------------------------- ------ 23.1/27.3 MB 3.9 MB/s eta 0:00:02
#    ---------------------------------- ----- 23.9/27.3 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------ --- 24.6/27.3 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------- -- 25.7/27.3 MB 3.9 MB/s eta 0:00:01
#    -------------------------------------- - 26.5/27.3 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  27.3/27.3 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 27.3/27.3 MB 3.8 MB/s  0:00:07
# Downloading websockets-16.0-cp313-cp313-win_amd64.whl (178 kB)
# Installing collected packages: websockets, watchdog, toml, tenacity, smmap, pyarrow, protobuf, itsdangerous, httptools, cachetools, blinker, pydeck, gitdb, gitpython, altair, streamlit
#
#    ----------------------------------------  0/16 [websockets]
#    ----------------------------------------  0/16 [websockets]
#    ----------------------------------------  0/16 [websockets]
#    ----------------------------------------  0/16 [websockets]
#    ----------------------------------------  0/16 [websockets]
#    ----------------------------------------  0/16 [websockets]
#    ----------------------------------------  0/16 [websockets]
#    ----------------------------------------  0/16 [websockets]
#    ----------------------------------------  0/16 [websockets]
#    ----------------------------------------  0/16 [websockets]
#    ----------------------------------------  0/16 [websockets]
#    -- -------------------------------------  1/16 [watchdog]
#    -- -------------------------------------  1/16 [watchdog]
#    -- -------------------------------------  1/16 [watchdog]
#    -- -------------------------------------  1/16 [watchdog]
#    -- -------------------------------------  1/16 [watchdog]
#    -- -------------------------------------  1/16 [watchdog]
#    ----- ----------------------------------  2/16 [toml]
#    ------- --------------------------------  3/16 [tenacity]
#    ------- --------------------------------  3/16 [tenacity]
#    ------- --------------------------------  3/16 [tenacity]
#    ---------- -----------------------------  4/16 [smmap]
#    ---------- -----------------------------  4/16 [smmap]
#    ------------ ---------------------------  5/16 [pyarrow]
#    ------------ ---------------------------  5/16 [pyarrow]
#    ------------ ---------------------------  5/16 [pyarrow]
#    ------------ ---------------------------  5/16 [pyarrow]
#    ------------ ---------------------------  5/16 [pyarrow]
#    ------------ ---------------------------  5/16 [pyarrow]
#    ------------ ---------------------------  5/16 [pyarrow]
#    ------------ ---------------------------  5/16 [pyarrow]
#    ------------ ---------------------------  5/16 [pyarrow]
#    ------------ ---------------------------  5/16 [pyarrow]
#    ------------ ---------------------------  5/16 [pyarrow]
#    ------------ ---------------------------  5/16 [pyarrow]
#    ------------ ---------------------------  5/16 [pyarrow]
#    ------------ ---------------------------  5/16 [pyarrow]
#    ------------ ---------------------------  5/16 [pyarrow]
#    ------------ ---------------------------  5/16 [pyarrow]
#    ------------ ---------------------------  5/16 [pyarrow]
#    ------------ ---------------------------  5/16 [pyarrow]
#    ------------ ---------------------------  5/16 [pyarrow]
#    ------------ ---------------------------  5/16 [pyarrow]
#    ------------ ---------------------------  5/16 [pyarrow]
#    ------------ ---------------------------  5/16 [pyarrow]
#    ------------ ---------------------------  5/16 [pyarrow]
#    ------------ ---------------------------  5/16 [pyarrow]
#    ------------ ---------------------------  5/16 [pyarrow]
#    ------------ ---------------------------  5/16 [pyarrow]
#    ------------ ---------------------------  5/16 [pyarrow]
#    ------------ ---------------------------  5/16 [pyarrow]
#    ------------ ---------------------------  5/16 [pyarrow]
#    ------------ ---------------------------  5/16 [pyarrow]
#    ------------ ---------------------------  5/16 [pyarrow]
#    ------------ ---------------------------  5/16 [pyarrow]
#    ------------ ---------------------------  5/16 [pyarrow]
#    ------------ ---------------------------  5/16 [pyarrow]
#    ------------ ---------------------------  5/16 [pyarrow]
#    ------------ ---------------------------  5/16 [pyarrow]
#    ------------ ---------------------------  5/16 [pyarrow]
#    ------------ ---------------------------  5/16 [pyarrow]
#    ------------ ---------------------------  5/16 [pyarrow]
#    ------------ ---------------------------  5/16 [pyarrow]
#    ------------ ---------------------------  5/16 [pyarrow]
#    ------------ ---------------------------  5/16 [pyarrow]
#    ------------ ---------------------------  5/16 [pyarrow]
#    ------------ ---------------------------  5/16 [pyarrow]
#    --------------- ------------------------  6/16 [protobuf]
#    --------------- ------------------------  6/16 [protobuf]
#    --------------- ------------------------  6/16 [protobuf]
#    --------------- ------------------------  6/16 [protobuf]
#    --------------- ------------------------  6/16 [protobuf]
#    --------------- ------------------------  6/16 [protobuf]
#    --------------- ------------------------  6/16 [protobuf]
#    --------------- ------------------------  6/16 [protobuf]
#    --------------- ------------------------  6/16 [protobuf]
#    --------------- ------------------------  6/16 [protobuf]
#    --------------- ------------------------  6/16 [protobuf]
#    --------------- ------------------------  6/16 [protobuf]
#    --------------- ------------------------  6/16 [protobuf]
#    --------------- ------------------------  6/16 [protobuf]
#    --------------- ------------------------  6/16 [protobuf]
#    ----------------- ----------------------  7/16 [itsdangerous]
#    ----------------- ----------------------  7/16 [itsdangerous]
#    -------------------- -------------------  8/16 [httptools]
#    -------------------- -------------------  8/16 [httptools]
#    ---------------------- -----------------  9/16 [cachetools]
#    ------------------------- -------------- 10/16 [blinker]
#    --------------------------- ------------ 11/16 [pydeck]
#    --------------------------- ------------ 11/16 [pydeck]
#    --------------------------- ------------ 11/16 [pydeck]
#    --------------------------- ------------ 11/16 [pydeck]
#    --------------------------- ------------ 11/16 [pydeck]
#    --------------------------- ------------ 11/16 [pydeck]
#    --------------------------- ------------ 11/16 [pydeck]
#    --------------------------- ------------ 11/16 [pydeck]
#    --------------------------- ------------ 11/16 [pydeck]
#    ------------------------------ --------- 12/16 [gitdb]
#    ------------------------------ --------- 12/16 [gitdb]
#    ------------------------------ --------- 12/16 [gitdb]
#    ------------------------------ --------- 12/16 [gitdb]
#    ------------------------------ --------- 12/16 [gitdb]
#    ------------------------------ --------- 12/16 [gitdb]
#    -------------------------------- ------- 13/16 [gitpython]
#    -------------------------------- ------- 13/16 [gitpython]
#    -------------------------------- ------- 13/16 [gitpython]
#    -------------------------------- ------- 13/16 [gitpython]
#    -------------------------------- ------- 13/16 [gitpython]
#    -------------------------------- ------- 13/16 [gitpython]
#    -------------------------------- ------- 13/16 [gitpython]
#    -------------------------------- ------- 13/16 [gitpython]
#    ----------------------------------- ---- 14/16 [altair]
#    ----------------------------------- ---- 14/16 [altair]
#    ----------------------------------- ---- 14/16 [altair]
#    ----------------------------------- ---- 14/16 [altair]
#    ----------------------------------- ---- 14/16 [altair]
#    ----------------------------------- ---- 14/16 [altair]
#    ----------------------------------- ---- 14/16 [altair]
#    ----------------------------------- ---- 14/16 [altair]
#    ----------------------------------- ---- 14/16 [altair]
#    ----------------------------------- ---- 14/16 [altair]
#    ----------------------------------- ---- 14/16 [altair]
#    ----------------------------------- ---- 14/16 [altair]
#    ----------------------------------- ---- 14/16 [altair]
#    ----------------------------------- ---- 14/16 [altair]
#    ----------------------------------- ---- 14/16 [altair]
#    ----------------------------------- ---- 14/16 [altair]
#    ----------------------------------- ---- 14/16 [altair]
#    ----------------------------------- ---- 14/16 [altair]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ------------------------------------- -- 15/16 [streamlit]
#    ---------------------------------------- 16/16 [streamlit]
#
# Successfully installed altair-6.2.1 blinker-1.9.0 cachetools-7.1.4 gitdb-4.0.12 gitpython-3.1.50 httptools-0.8.0 itsdangerous-2.2.0 protobuf-7.35.1 pyarrow-24.0.0 pydeck-0.9.2 smmap-5.0.3 streamlit-1.58.0 tenacity-9.1.4 toml-0.10.2 watchdog-6.0.0 websockets-16.0

# %%
import streamlit as st
import pandas as pd
import joblib

# %%
model=joblib.load("../models/final_credit_risk_model.pkl")
st.title("Credit Risk Prediction")
age=st.number_input("Age",18,100,30)
credit_amount=st.number_input(
    "Credit Amount",
    100,
    20000,
    5000,
)
duration=st.number_input("Duration(months)",
                         1,
                         72,
                         12
)
job=st.selectbox(
    "Job",[0,1,2,3] )
sex=st.selectbox(
    "Sex",
    ["male","female"]
)
housing=st.selectbox(
    "Housing",
    ["own","rent","free"]
)
# Out:
# 2026-06-22 12:25:22.338 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:25:22.340 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:25:22.341 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:25:22.343 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:25:22.345 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:25:22.346 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:25:22.348 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:25:22.350 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:25:22.351 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:25:22.353 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:25:22.355 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:25:22.357 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:25:22.359 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:25:22.365 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:25:22.367 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:25:22.369 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:25:22.370 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:25:22.372 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:25:22.374 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:25:22.375 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:25:22.377 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:25:22.378 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:25:22.380 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:25:22.383 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:25:22.384 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:25:22.385 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:25:22.386 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:25:22.388 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:25:22.390 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:25:22.392 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:25:22.393 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:25:22.395 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:25:22.396 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:25:22.397 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:25:22.399 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:25:22.400 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:25:22.401 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:25:22.402 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:25:22.403 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:25:22.404 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:25:22.406 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:25:22.407 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:25:22.408 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:25:22.410 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:25:22.411 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
saving=st.selectbox(
    "saving Accounts",
    ["little","moderate","rich","unknown"]
)
checking=st.selectbox(
    "Checking Account",
    ["little","moderate","rich",
     "unknown"]
)
purpose = st.selectbox(
    "Purpose",
    [
        "car",
        "education",
        "radio/TV",
        "furniture/equipment",
        "business"
    ]
)
# Out:
# 2026-06-22 12:27:45.262 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:27:45.265 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:27:45.266 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:27:45.267 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:27:45.268 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:27:45.269 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:27:45.271 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:27:45.272 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:27:45.273 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:27:45.275 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:27:45.276 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:27:45.278 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:27:45.279 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:27:45.281 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:27:45.284 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:27:45.285 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:27:45.287 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:27:45.288 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:27:45.290 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:27:45.292 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:27:45.293 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
columns=joblib.load(
    "../models/columns.pkl"
)

# %%
if st.button("Prdict Risk"):
    pred=model.predict(input_df)
    if pred[0]==1:
        st.success(
            "Good Credit Risk"
        )
    else:
        st.error(
            "Bad Credit Risk"
        )
# Out:
# 2026-06-22 12:35:40.425 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:35:40.428 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:35:40.431 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:35:40.433 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:35:40.435 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 12:35:40.437 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
